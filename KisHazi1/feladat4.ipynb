# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.io import wavfile as wf

# %%
# We read the audio file into a dataset and samplerate variable
samplerate, data = wf.read("resources/sound.wav")

# %%
# We plot the spectogram
plt.specgram(data, Fs=samplerate)
# Out:
# (array([[2.25676164e+00, 1.63906259e-01, 3.58202026e+00, ...,
#          1.67520065e+01, 9.25884280e+01, 6.49382177e-02],
#         [1.81596973e+01, 6.49517921e+00, 1.76827638e+01, ...,
#          4.06215247e+01, 1.83561671e+02, 3.48155575e+00],
#         [2.63450050e+01, 3.82569509e+00, 8.31334094e+00, ...,
#          7.27368048e+00, 6.62548137e+01, 6.63999842e+00],
#         ...,
#         [7.38593839e-06, 1.01838776e-05, 3.03434865e-06, ...,
#          2.69911732e-05, 1.44722074e-06, 2.83267139e-06],
#         [9.61895895e-06, 7.20027315e-07, 1.16770866e-06, ...,
#          1.38964207e-05, 3.98924007e-06, 1.00285272e-05],
#         [2.93001650e-07, 7.36795002e-07, 2.97321520e-08, ...,
#          1.99883625e-06, 3.32500313e-06, 4.57930465e-06]]),
#  array([    0.      ,   172.265625,   344.53125 ,   516.796875,
#           689.0625  ,   861.328125,  1033.59375 ,  1205.859375,
#          1378.125   ,  1550.390625,  1722.65625 ,  1894.921875,
# ...
